# %%
# !pip install openai --upgrade
# Out:
# Collecting openai
#   Downloading openai-0.28.1-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai) (3.8.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.1)
# Installing collected packages: openai
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# Successfully installed openai-0.28.1

# %%
import pandas as pd
import os
import openai
from dateutil.parser import parse
# SYSTEM PROMPT
SYSTEM_PROMPT = """

Task:
Imagine you are a data analyst working in a hospital tasked with evaluating the sequential validity of time-related fields in a healthcare dataset. Your role involves assessing the quality of medical data across various hospitals.
When you receive medical tabular data, it's crucial to distinguish and understand the chronological order of the column names.

Procedure:
Analyze various CSV files from different researchers. The variable names might be explicit, but sometimes they might be abbreviated. Consider this in the context of medical tabular data. For example:
EDREGTIME (Emergency Department registration time)
ADMITIME (Admission time)
DISCHTIME (Discharge time)
DEATHTIME (Death time)
Infer the full meaning of variable names like Admitime.
From the input columns, identify and exclude columns that aren't related to medical events.
Determine the sequence and relationship of the relevant columns without including additional information. Express the order of medical data using logical operators.
Use symbols like "<" for "less than", ">" for "greater than", ">=" for "greater than or equal to" to define relationships, and "&&" mark the end of the sentence.

Note:
Make sure to output the exact column name, becareful of lowercase and uppercase. When interpreting medical data columns like discharge_date, admission_date, diagnosis_date, medication_start_date, and medication_end_date, avoid making specific or strict assumptions about the order of events that might not be universally valid. Instead, only establish general sequences that have broad applicability. For instance, it's universally valid that medication has a start and an end date, so medication_start_date should always be on or before medication_end_date. Similarly, a patient's date of admission should always be before their date of discharge. However, do not make assumptions like diagnosis_date is always before admission_date as this is not universally true. The goal is to capture the broadest and most general sequence of events without being overly prescriptive.

Output format:
1. Columns to exclude: List the columns that aren't directly related to the medical sequence.
2. Reason for exclusion: Provide reasons for why certain columns were excluded from the medical sequence.
3. Relevant columns: Describe the medical significance of each column in a dictionary format
ADMITTIME: The time a patient is admitted to the hospital.
DISCHTIME: The time a patient is discharged from the hospital.
DEATHTIME: The time a patient dies.
EDREGTIME: The time a patient registers at the emergency department.
4. Sequential: Define the logical sequence of the columns. Make sure to use the exact variable name including lower and uppercase.
5. Sequence rationale: Describe the rationale or reasoning behind the defined sequence.

Example:
MIMIC data

Input: ADMITTIME, DISCHTIME, DEATHTIME, EDREGTIME, EDOUTTIME, LABTEST_DATE, MEDICATION_DATE, SURGERY_DATE, FOLLOWUP_DATE, HEIGHT, WEIGHT, STORETIME, VALUE

Output:
1. Columns to exclude: HEIGHT, WEIGHT, STORETIME, VALUE

2. Reason for exclusion: These columns do not directly represent chronological medical events or timestamps related to patient care in the MIMIC dataset.

3. Relevant columns:
ADMITTIME: The time a patient is admitted to the hospital.
DISCHTIME: The time a patient is discharged from the hospital.
DEATHTIME: The time a patient dies.
EDREGTIME: The time a patient registers at the emergency department.
EDOUTTIME: The time a patient leaves the emergency department.
LABTEST_DATE: The time a lab test was conducted.
MEDICATION_DATE: The time medication was administered.
SURGERY_DATE: The time surgery was conducted.
FOLLOWUP_DATE: The time of a patient's follow-up visit.
RADIOLOGY_DATE: The time a radiological test was conducted.

4. Sequential:
EDREGTIME < EDOUTTIME &&
ADMITTIME < DISCHTIME &&

5. Sequence rationale:
The patient first registers at the emergency department, then leaves it.
Once admitted, various medical events like lab tests, medications, surgeries, radiological tests, and follow-ups can occur in different order so we omit them in our sequence. Instead, we show the more logical and general sequence which is the patient admits in the hospital and then discharges.


Input: discharge_date, admission_date, diagnosis_date, medication_start_date, medication_end_date, age_at_recruitment, ethnicitiy, bmi, smoking_status, blood_glucose

Output:

1. Columns to exclude: age_at_recruitment, gender, ethnicitiy, bmi, smoking_status, alcohol_frequency

2. Reason for exclusion: These columns do not directly represent chronological medical events or timestamps related to patient care. Age_at_recruitment, gender, and ethnicity are demographic information, bmi, smoking_status, alcohol_frequency are health status or lifestyle information but not time-related.

3. Relevant columns:

DISCHARGE_DATE: The date a patient was discharged from the hospital.
ADMISSION_DATE: The date when a patient was admitted.
DIAGNOSIS_DATE: The date when a patient was diagnosed.
MEDICATION_START_DATE: The date when medication was started.
MEDICATION_END_DATE: The date when medication was ended.

4. Sequential:
MEDICATION_START_DATE <= MEDICATION_END_DATE &&
ADMISSION_DATE < DISCHARGE_DATE &&

5. Sequence rationale:
Medication administration has a clear start and end, so the start date should always be on or before the end date. Similarly, the date of admission to a hospital should always precede the discharge date. These sequences capture general, universally valid relationships in medical data without making assumptions about the specific order of other events.

"""

# Helper function to check if a string is a date
def is_date(string):
    try:
        parse(string)
        print(f"Checked date: {string} is valid.")
        return True
    except ValueError:
        print(f"Checked date: {string} is invalid.")
        return False


# Validate a single comparison, returns False if the comparison fails
def validate_comparison(row, left_col, right_col, operator):
    # Convert to datetime if both values are dates
    left_col = left_col.lower()
    right_col = right_col.lower()

    if is_date(str(row[left_col])) and is_date(str(row[right_col])):
        left_val = pd.to_datetime(row[left_col])
        right_val = pd.to_datetime(row[right_col])

        if operator == "<" and not left_val < right_val:
            return False
        elif operator == "<=" and not left_val <= right_val:
            return False
        elif operator == ">" and not left_val > right_val:
            return False
        elif operator == ">=" and not left_val >= right_val:
            return False
    return True

# 1. Importing data
def import_data(file_path):
    try:
        df = pd.read_csv(file_path)
        print(f"Data imported successfully with columns: {df.columns.tolist()}")
        df.columns = df.columns.str.lower()  # Convert column names to lowercase
        return df
    except Exception as e:
        print(f"Error importing data: {e}")


def get_gpt_output(df, temperature=0):
    # Filtering columns based on data type and column name patterns
    timestamp_columns = df.columns.tolist()

    openai.api_key = os.getenv("OPENAI_API_KEY")
    openai.api_key = "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"

    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user", "content": ", ".join(timestamp_columns)}
        ]
    )
    return response['choices'][0]['message']['content']

# 3. Check column order
def extract_sequence_order(gpt_output):
    lines = gpt_output.split('\n')
    sequence = ""
    capturing = False

    for line in lines:
        line = line.strip()
        if line.startswith("4. Sequential:"):
            capturing = True
            # Start capturing the sequence, remove the "4. Sequential:" part
            sequence += line.replace("4. Sequential:", "").strip() + " "
        elif capturing:
            print(line)
            if line.startswith("5. Sequence rationale:"):
                # Stop capturing if the next section starts
                break
            if "&&" not in line:
                # If there's no "&&", it's part of the sequence
                sequence += line + " "
            else:
                # If "&&" is found, append the part of the line before "&&"
                sequence += line + " "

    return sequence.strip()

# 4. Validation
def validate_rows(df, sequence):
    valid_rows = 0
    invalid_rows = []
    conditions = [cond.strip().replace("<=", "≤").replace(">=", "≥") for cond in sequence.split("&&") if cond.strip()]

    for index, row in df.iterrows():
        valid = True
        row_errors = []
        for condition in conditions:
            parts = ''
            operator = ''
            if "≤" in condition or "≥" in condition:
                parts = condition.split("≤") if "≤" in condition else condition.split("≥")
                operator = "<=" if "≤" in condition else ">="
            elif "<" in condition or ">" in condition:
                parts = condition.split("<") if "<" in condition else condition.split(">")
                operator = "<" if "<" in condition else ">"

            for i in range(len(parts) - 1):
                left_col = parts[i].replace("≤", "").replace("≥", "").strip()
                right_col = parts[i + 1].replace("≤", "").replace("≥", "").strip()

                # if "≤" in parts[i + 1]:
                #     operator = "<="
                # elif "≥" in parts[i + 1]:
                #     operator = ">="

                if not validate_comparison(row, left_col, right_col, operator):
                    valid = False
                    #change operator
                    comp_symbol = change_operator(operator)
                    row_errors.append(f"{left_col} {comp_symbol} {right_col}")

        # Print the result of each comparison
        if valid:
            print(f"Row {index} is valid.")
        else:
            print(f"Row {index} is invalid due to: {', '.join(row_errors)}")

        if valid:
            valid_rows += 1
        else:
            invalid_rows.append((index, row_errors))

    # Print the summary of validation
    print(f"Total valid rows: {valid_rows}, Invalid rows: {len(invalid_rows)}")
    return valid_rows


# 5. Validity Calculation
def calculate_validity_percentage(df, valid_rows):
    total_rows = len(df)
    return (valid_rows / total_rows) * 100

#6. Change operator
def change_operator(operator):
    oper = ''
    if operator == '<':
        oper = '>='
    elif operator == '>':
        oper = '<='
    elif operator == '<=':
        oper = '>'
    elif operator == '>=':
        oper = '<'
    else:
        oper = operator

    return oper

# Main execution block
if __name__ == "__main__":
    file_path = "/content/split_1.csv"  # Update this path as needed
    df = import_data(file_path)

    if df is not None:
        gpt_output = get_gpt_output(df)
        print("GPT Output:")
        print(gpt_output)

        sequence = extract_sequence_order(gpt_output)
        print(f"Extracted sequence: {sequence}")

        valid_rows = validate_rows(df, sequence)
        if valid_rows is not None:
            percentage = calculate_validity_percentage(df, valid_rows)
            print(f"Percentage of valid rows: {percentage:.2f}%")
# Out:
# Data imported successfully with columns: ['STARTDATE', 'ENDDATE', 'SUBJECT_ID', 'ADMITTIME', 'DISCHTIME']
# GPT Output:
# Output:
#
# 1. Columns to exclude: subject_id
#
# 2. Reason for exclusion: The column 'subject_id' is an identifier and does not directly represent a medical event or timestamp.
#
# 3. Relevant columns:
#
# STARTDATE: The day an activity, such as a medication regimen, begins.
#
# ENDDATE: The day an activity, such as a medication regimen, ends.
#
# ADMITTIME: The time a patient is admitted to the hospital.
#
# DISCHTIME: The time a patient is discharged from the hospital.
#
# 4. Sequential:
#
# STARTDATE <= ENDDATE &&
# ADMITTIME < DISCHTIME
#
# 5. Sequence rationale:
# The 'STARTDATE' and 'ENDDATE' likely refers to a period of a certain activity, such as medication administration, therefore the start should always be on or before the end. The 'ADMITTIME' and 'DISCHTIME' represent the period a patient is in the hospital, hence, the admission should always take place before the discharge.
#
# STARTDATE <= ENDDATE &&
# ADMITTIME < DISCHTIME
#
# 5. Sequence rationale:
# Extracted sequence: STARTDATE <= ENDDATE && ADMITTIME < DISCHTIME
# Checked date: 2180-11-15 00:00:00.000000 UTC is valid.
# Checked date: 2180-11-15 00:00:00.000000 UTC is valid.
# Checked date: 2180-11-01 01:38:00.000000 UTC is valid.
# Checked date: 2180-11-20 14:45:00.000000 UTC is valid.
# Row 0 is valid.
# Checked date: 2180-11-15 00:00:00.000000 UTC is valid.
# Checked date: 2180-11-15 00:00:00.000000 UTC is valid.
# Checked date: 2177-02-25 04:31:00.000000 UTC is valid.
# Checked date: 2177-02-28 16:00:00.000000 UTC is valid.
# Row 1 is valid.
# Checked date: 2113-10-03 00:00:00.000000 UTC is valid.
# Checked date: 2113-10-04 00:00:00.000000 UTC is valid.
# Checked date: 2113-10-02 11:36:00.000000 UTC is valid.
# Checked date: 2113-10-06 15:00:00.000000 UTC is valid.
# Row 2 is valid.
# Checked date: 2120-09-27 00:00:00.000000 UTC is valid.
# Checked date: 2120-09-28 00:00:00.000000 UTC is valid.
# Checked date: 2120-09-18 08:00:00.000000 UTC is valid.
# Checked date: 2120-10-10 16:35:00.000000 UTC is valid.
# Row 3 is valid.
# Checked date: 2137-06-20 00:00:00.000000 UTC is valid.
# Checked date: 2137-06-21 00:00:00.000000 UTC is valid.
# Checked date: 2137-06-11 11:09:00.000000 UTC is valid.
# Checked date: 2137-07-22 19:20:00.000000 UTC is valid.
# Row 4 is valid.
# Checked date: 2139-05-23 00:00:00.000000 UTC is valid.
# Checked date: 2139-05-24 00:00:00.000000 UTC is valid.
# Checked date: 2139-10-05 02:09:00.000000 UTC is valid.
# Checked date: 2139-10-06 12:00:00.000000 UTC is valid.
# Row 5 is valid.
# Checked date: 2139-05-23 00:00:00.000000 UTC is valid.
# Checked date: 2139-05-24 00:00:00.000000 UTC is valid.
# Checked date: 2138-06-11 11:00:00.000000 UTC is valid.
# Checked date: 2138-07-11 14:23:00.000000 UTC is valid.
# Row 6 is valid.
# Checked date: 2139-05-23 00:00:00.000000 UTC is valid.
# Checked date: 2139-05-24 00:00:00.000000 UTC is valid.
# Checked date: 2138-08-14 17:46:00.000000 UTC is valid.
# Checked date: 2138-09-02 13:18:00.000000 UTC is valid.
# Row 7 is valid.
# Checked date: 2139-05-23 00:00:00.000000 UTC is valid.
# Checked date: 2139-05-24 00:00:00.000000 UTC is valid.
# Checked date: 2138-07-14 14:02:00.000000 UTC is valid.
# Checked date: 2138-07-31 11:44:00.000000 UTC is valid.
# Row 8 is valid.
# Checked date: 2139-05-23 00:00:00.000000 UTC is valid.
# Checked date: 2139-05-24 00:00:00.000000 UTC is valid.
# Checked date: 2139-02-20 17:43:00.000000 UTC is valid.
# Checked date: 2139-03-05 13:05:00.000000 UTC is valid.
# Row 9 is valid.
# Checked date: 2139-05-23 00:00:00.000000 UTC is valid.
# Checked date: 2139-05-24 00:00:00.000000 UTC is valid.
# Checked date: 2139-05-08 10:30:00.000000 UTC is valid.
# Checked date: 2139-06-09 13:15:00.000000 UTC is valid.
# Row 10 is valid.
# Checked date: 2139-05-23 00:00:00.000000 UTC is valid.
# Checked date: 2139-05-24 00:00:00.000000 UTC is valid.
# Checked date: 2138-10-15 23:22:00.000000 UTC is valid.
# Checked date: 2138-11-13 11:10:00.000000 UTC is valid.
# Row 11 is valid.
# Checked date: 2139-03-05 00:00:00.000000 UTC is valid.
# Checked date: 2139-03-06 00:00:00.000000 UTC is valid.
# Checked date: 2133-09-30 14:06:00.000000 UTC is valid.
# Checked date: 2133-10-13 17:15:00.000000 UTC is valid.
# Row 12 is valid.
# Checked date: 2139-03-05 00:00:00.000000 UTC is valid.
# Checked date: 2139-03-06 00:00:00.000000 UTC is valid.
# Checked date: 2139-10-10 00:48:00.000000 UTC is valid.
# Checked date: 2139-10-10 08:50:00.000000 UTC is valid.
# Row 13 is valid.
# Checked date: 2139-03-05 00:00:00.000000 UTC is valid.
# Checked date: 2139-03-06 00:00:00.000000 UTC is valid.
# Checked date: 2135-05-22 21:18:00.000000 UTC is valid.
# Checked date: 2135-06-04 14:45:00.000000 UTC is valid.
# Row 14 is valid.
# Checked date: 2139-03-05 00:00:00.000000 UTC is valid.
# Checked date: 2139-03-06 00:00:00.000000 UTC is valid.
# Checked date: 2137-06-30 22:38:00.000000 UTC is valid.
# Checked date: 2137-07-06 17:00:00.000000 UTC is valid.
# Row 15 is valid.
# Checked date: 2139-03-05 00:00:00.000000 UTC is valid.
# Checked date: 2139-03-06 00:00:00.000000 UTC is valid.
# Checked date: 2138-11-12 00:43:00.000000 UTC is valid.
# Checked date: 2138-11-18 15:21:00.000000 UTC is valid.
# Row 16 is valid.
# Checked date: 2139-03-05 00:00:00.000000 UTC is valid.
# Checked date: 2139-03-06 00:00:00.000000 UTC is valid.
# Checked date: 2139-08-24 17:02:00.000000 UTC is valid.
# Checked date: 2139-09-04 17:00:00.000000 UTC is valid.
# Row 17 is valid.
# Checked date: 2139-03-05 00:00:00.000000 UTC is valid.
# Checked date: 2139-03-06 00:00:00.000000 UTC is valid.
# Checked date: 2139-03-03 20:09:00.000000 UTC is valid.
# Checked date: 2139-03-21 15:45:00.000000 UTC is valid.
# Row 18 is valid.
# Checked date: 2139-03-05 00:00:00.000000 UTC is valid.
# Checked date: 2139-03-06 00:00:00.000000 UTC is valid.
# Checked date: 2132-03-29 17:02:00.000000 UTC is valid.
# Checked date: 2132-04-18 14:34:00.000000 UTC is valid.
# Row 19 is valid.
# Checked date: 2139-03-05 00:00:00.000000 UTC is valid.
# Checked date: 2139-03-06 00:00:00.000000 UTC is valid.
# Checked date: 2137-07-23 23:20:00.000000 UTC is valid.
# Checked date: 2137-08-14 14:30:00.000000 UTC is valid.
# Row 20 is valid.
# Checked date: 2138-04-18 00:00:00.000000 UTC is valid.
# Checked date: 2138-04-19 00:00:00.000000 UTC is valid.
# Checked date: 2138-04-10 22:44:00.000000 UTC is valid.
# Checked date: 2138-04-19 14:00:00.000000 UTC is valid.
# Row 21 is valid.
# Checked date: 2138-04-18 00:00:00.000000 UTC is valid.
# Checked date: 2138-04-19 00:00:00.000000 UTC is valid.
# Checked date: 2140-11-16 05:23:00.000000 UTC is valid.
# Checked date: 2140-11-24 16:15:00.000000 UTC is valid.
# Row 22 is valid.
# Checked date: 2193-02-12 00:00:00.000000 UTC is valid.
# Checked date: 2193-02-13 00:00:00.000000 UTC is valid.
# Checked date: 2193-01-09 15:50:00.000000 UTC is valid.
# Checked date: 2193-02-18 09:30:00.000000 UTC is valid.
# Row 23 is valid.
# Checked date: 2140-11-14 00:00:00.000000 UTC is valid.
# Checked date: 2140-11-15 00:00:00.000000 UTC is valid.
# Checked date: 2140-06-03 06:20:00.000000 UTC is valid.
# Checked date: 2140-07-04 16:44:00.000000 UTC is valid.
# Row 24 is valid.
# Checked date: 2140-11-14 00:00:00.000000 UTC is valid.
# Checked date: 2140-11-15 00:00:00.000000 UTC is valid.
# Checked date: 2140-11-14 14:44:00.000000 UTC is valid.
# Checked date: 2140-11-17 16:42:00.000000 UTC is valid.
# Row 25 is valid.
# Checked date: 2140-11-14 00:00:00.000000 UTC is valid.
# Checked date: 2140-11-15 00:00:00.000000 UTC is valid.
# Checked date: 2141-12-14 18:02:00.000000 UTC is valid.
# Checked date: 2141-12-19 13:35:00.000000 UTC is valid.
# Row 26 is valid.
# Checked date: 2140-11-14 00:00:00.000000 UTC is valid.
# Checked date: 2140-11-15 00:00:00.000000 UTC is valid.
# Checked date: 2143-07-16 19:02:00.000000 UTC is valid.
# Checked date: 2143-07-19 20:34:00.000000 UTC is valid.
# Row 27 is valid.
# Checked date: 2140-11-14 00:00:00.000000 UTC is valid.
# Checked date: 2140-11-15 00:00:00.000000 UTC is valid.
# Checked date: 2143-12-26 21:29:00.000000 UTC is valid.
# Checked date: 2143-12-27 15:15:00.000000 UTC is valid.
# Row 28 is valid.
# Checked date: 2140-11-14 00:00:00.000000 UTC is valid.
# Checked date: 2140-11-15 00:00:00.000000 UTC is valid.
# Checked date: 2140-07-11 02:34:00.000000 UTC is valid.
# Checked date: 2140-07-25 16:35:00.000000 UTC is valid.
# Row 29 is valid.
# Checked date: 2156-04-03 00:00:00.000000 UTC is valid.
# Checked date: 2156-04-05 00:00:00.000000 UTC is valid.
# Checked date: 2156-03-26 13:08:00.000000 UTC is valid.
# Checked date: 2156-04-07 20:38:00.000000 UTC is valid.
# Row 30 is valid.
# Checked date: 2114-04-16 00:00:00.000000 UTC is valid.
# Checked date: 2114-05-22 00:00:00.000000 UTC is valid.
# Checked date: 2114-03-20 15:25:00.000000 UTC is valid.
# Checked date: 2114-05-22 14:15:00.000000 UTC is valid.
# Row 31 is valid.
# Checked date: 2145-10-09 00:00:00.000000 UTC is valid.
# Checked date: 2145-10-19 00:00:00.000000 UTC is valid.
# Checked date: 2145-10-03 14:14:00.000000 UTC is valid.
# Checked date: 2145-10-19 14:53:00.000000 UTC is valid.
# Row 32 is valid.
# Checked date: 2171-10-30 00:00:00.000000 UTC is valid.
# Checked date: 2171-11-06 00:00:00.000000 UTC is valid.
# Checked date: 2171-10-22 17:08:00.000000 UTC is valid.
# Checked date: 2171-11-06 10:32:00.000000 UTC is valid.
# Row 33 is valid.
# Checked date: 2191-11-27 00:00:00.000000 UTC is valid.
# Checked date: 2191-11-30 00:00:00.000000 UTC is valid.
# Checked date: 2191-11-08 17:59:00.000000 UTC is valid.
# Checked date: 2191-11-16 18:22:00.000000 UTC is valid.
# Row 34 is valid.
# Checked date: 2191-11-27 00:00:00.000000 UTC is valid.
# Checked date: 2191-11-30 00:00:00.000000 UTC is valid.
# Checked date: 2191-11-23 21:02:00.000000 UTC is valid.
# Checked date: 2191-12-09 07:55:00.000000 UTC is valid.
# Row 35 is valid.
# Checked date: 2160-03-27 00:00:00.000000 UTC is valid.
# Checked date: 2160-03-30 00:00:00.000000 UTC is valid.
# Checked date: 2160-03-27 22:33:00.000000 UTC is valid.
# Checked date: 2160-03-30 15:04:00.000000 UTC is valid.
# Row 36 is valid.
# Checked date: 2106-03-29 00:00:00.000000 UTC is valid.
# Checked date: 2106-04-03 00:00:00.000000 UTC is valid.
# Checked date: 2108-12-01 19:01:00.000000 UTC is valid.
# Checked date: 2108-12-07 13:00:00.000000 UTC is valid.
# Row 37 is valid.
# Checked date: 2106-03-29 00:00:00.000000 UTC is valid.
# Checked date: 2106-04-03 00:00:00.000000 UTC is valid.
# Checked date: 2109-09-01 00:56:00.000000 UTC is valid.
# Checked date: 2109-09-06 17:36:00.000000 UTC is valid.
# Row 38 is valid.
# Checked date: 2106-03-29 00:00:00.000000 UTC is valid.
# Checked date: 2106-04-03 00:00:00.000000 UTC is valid.
# Checked date: 2106-03-23 20:45:00.000000 UTC is valid.
# Checked date: 2106-04-12 13:30:00.000000 UTC is valid.
# Row 39 is valid.
# Checked date: 2106-03-29 00:00:00.000000 UTC is valid.
# Checked date: 2106-04-03 00:00:00.000000 UTC is valid.
# Checked date: 2106-08-09 14:48:00.000000 UTC is valid.
# Checked date: 2106-08-23 13:45:00.000000 UTC is valid.
# Row 40 is valid.
# Checked date: 2106-03-29 00:00:00.000000 UTC is valid.
# Checked date: 2106-04-03 00:00:00.000000 UTC is valid.
# Checked date: 2107-04-11 20:23:00.000000 UTC is valid.
# Checked date: 2107-04-16 15:15:00.000000 UTC is valid.
# Row 41 is valid.
# Checked date: 2106-03-29 00:00:00.000000 UTC is valid.
# Checked date: 2106-04-03 00:00:00.000000 UTC is valid.
# Checked date: 2107-07-28 23:13:00.000000 UTC is valid.
# Checked date: 2107-08-04 15:00:00.000000 UTC is valid.
# Row 42 is valid.
# Checked date: 2106-03-29 00:00:00.000000 UTC is valid.
# Checked date: 2106-04-03 00:00:00.000000 UTC is valid.
# Checked date: 2108-05-15 22:21:00.000000 UTC is valid.
# Checked date: 2108-05-18 18:08:00.000000 UTC is valid.
# Row 43 is valid.
# Checked date: 2106-03-29 00:00:00.000000 UTC is valid.
# Checked date: 2106-04-03 00:00:00.000000 UTC is valid.
# Checked date: 2108-08-01 21:58:00.000000 UTC is valid.
# Checked date: 2108-08-08 12:55:00.000000 UTC is valid.
# Row 44 is valid.
# Checked date: 2106-03-29 00:00:00.000000 UTC is valid.
# Checked date: 2106-04-03 00:00:00.000000 UTC is valid.
# Checked date: 2109-01-06 23:04:00.000000 UTC is valid.
# Checked date: 2109-01-11 12:00:00.000000 UTC is valid.
# Row 45 is valid.
# Checked date: 2106-03-29 00:00:00.000000 UTC is valid.
# Checked date: 2106-04-03 00:00:00.000000 UTC is valid.
# Checked date: 2108-10-18 04:51:00.000000 UTC is valid.
# Checked date: 2108-11-06 12:13:00.000000 UTC is valid.
# Row 46 is valid.
# Checked date: 2106-03-29 00:00:00.000000 UTC is valid.
# Checked date: 2106-04-03 00:00:00.000000 UTC is valid.
# Checked date: 2108-12-18 19:48:00.000000 UTC is valid.
# Checked date: 2109-01-03 13:40:00.000000 UTC is valid.
# Row 47 is valid.
# Checked date: 2106-03-29 00:00:00.000000 UTC is valid.
# Checked date: 2106-04-03 00:00:00.000000 UTC is valid.
# Checked date: 2108-09-04 21:58:00.000000 UTC is valid.
# Checked date: 2108-09-26 21:00:00.000000 UTC is valid.
# Row 48 is valid.
# Checked date: 2176-06-25 00:00:00.000000 UTC is valid.
# Checked date: 2176-07-04 00:00:00.000000 UTC is valid.
# Checked date: 2176-03-30 17:19:00.000000 UTC is valid.
# Checked date: 2176-04-10 14:45:00.000000 UTC is valid.
# Row 49 is valid.
# Checked date: 2176-06-25 00:00:00.000000 UTC is valid.
# Checked date: 2176-07-04 00:00:00.000000 UTC is valid.
# Checked date: 2176-06-19 00:00:00.000000 UTC is valid.
# Checked date: 2176-07-08 17:00:00.000000 UTC is valid.
# Row 50 is valid.
# Checked date: 2170-01-25 00:00:00.000000 UTC is valid.
# Checked date: 2170-01-25 00:00:00.000000 UTC is valid.
# Checked date: 2168-06-20 15:15:00.000000 UTC is valid.
# Checked date: 2168-06-29 17:30:00.000000 UTC is valid.
# Row 51 is valid.
# Checked date: 2170-01-25 00:00:00.000000 UTC is valid.
# Checked date: 2170-01-25 00:00:00.000000 UTC is valid.
# Checked date: 2169-08-29 20:06:00.000000 UTC is valid.
# Checked date: 2169-09-04 14:25:00.000000 UTC is valid.
# Row 52 is valid.
# Checked date: 2170-01-25 00:00:00.000000 UTC is valid.
# Checked date: 2170-01-25 00:00:00.000000 UTC is valid.
# Checked date: 2170-01-22 13:09:00.000000 UTC is valid.
# Checked date: 2170-01-30 11:04:00.000000 UTC is valid.
# Row 53 is valid.
# Checked date: 2127-06-29 00:00:00.000000 UTC is valid.
# Checked date: 2127-06-30 00:00:00.000000 UTC is valid.
# Checked date: 2127-06-27 00:12:00.000000 UTC is valid.
# Checked date: 2127-07-02 13:41:00.000000 UTC is valid.
# Row 54 is valid.
# Checked date: 2144-04-05 00:00:00.000000 UTC is valid.
# Checked date: 2144-04-08 00:00:00.000000 UTC is valid.
# Checked date: 2144-07-23 13:52:00.000000 UTC is valid.
# Checked date: 2144-07-27 15:15:00.000000 UTC is valid.
# Row 55 is valid.
# Checked date: 2144-04-05 00:00:00.000000 UTC is valid.
# Checked date: 2144-04-08 00:00:00.000000 UTC is valid.
# Checked date: 2136-06-04 05:36:00.000000 UTC is valid.
# Checked date: 2136-06-23 17:00:00.000000 UTC is valid.
# Row 56 is valid.
# Checked date: 2144-04-05 00:00:00.000000 UTC is valid.
# Checked date: 2144-04-08 00:00:00.000000 UTC is valid.
# Checked date: 2137-12-07 05:54:00.000000 UTC is valid.
# Checked date: 2137-12-14 14:23:00.000000 UTC is valid.
# Row 57 is valid.
# Checked date: 2144-04-05 00:00:00.000000 UTC is valid.
# Checked date: 2144-04-08 00:00:00.000000 UTC is valid.
# Checked date: 2144-03-13 21:21:00.000000 UTC is valid.
# Checked date: 2144-04-10 19:00:00.000000 UTC is valid.
# Row 58 is valid.
# Checked date: 2144-04-05 00:00:00.000000 UTC is valid.
# Checked date: 2144-04-08 00:00:00.000000 UTC is valid.
# Checked date: 2136-10-23 14:33:00.000000 UTC is valid.
# Checked date: 2136-11-14 18:10:00.000000 UTC is valid.
# Row 59 is valid.
# Checked date: 2144-04-05 00:00:00.000000 UTC is valid.
# Checked date: 2144-04-08 00:00:00.000000 UTC is valid.
# Checked date: 2137-02-19 19:45:00.000000 UTC is valid.
# Checked date: 2137-02-27 16:00:00.000000 UTC is valid.
# Row 60 is valid.
# Checked date: 2170-11-08 00:00:00.000000 UTC is valid.
# Checked date: 2170-12-06 00:00:00.000000 UTC is valid.
# Checked date: 2170-09-23 20:54:00.000000 UTC is valid.
# Checked date: 2170-12-06 12:30:00.000000 UTC is valid.
# Row 61 is valid.
# Checked date: 2176-08-02 00:00:00.000000 UTC is valid.
# Checked date: 2176-08-14 00:00:00.000000 UTC is valid.
# Checked date: 2176-08-02 17:54:00.000000 UTC is valid.
# Checked date: 2176-08-14 17:55:00.000000 UTC is valid.
# Row 62 is valid.
# Checked date: 2126-02-26 00:00:00.000000 UTC is valid.
# Checked date: 2126-02-25 00:00:00.000000 UTC is valid.
# Checked date: 2126-02-21 20:09:00.000000 UTC is valid.
# Checked date: 2126-03-02 15:00:00.000000 UTC is valid.
# Row 63 is invalid due to: STARTDATE > ENDDATE
# Checked date: 2126-02-26 00:00:00.000000 UTC is valid.
# Checked date: 2126-02-25 00:00:00.000000 UTC is valid.
# Checked date: 2129-08-19 13:30:00.000000 UTC is valid.
# Checked date: 2129-08-23 11:45:00.000000 UTC is valid.
# Row 64 is invalid due to: STARTDATE > ENDDATE
# Checked date: 2126-02-26 00:00:00.000000 UTC is valid.
# Checked date: 2126-02-25 00:00:00.000000 UTC is valid.
# Checked date: 2126-07-25 19:49:00.000000 UTC is valid.
# Checked date: 2126-08-13 19:00:00.000000 UTC is valid.
# Row 65 is invalid due to: STARTDATE > ENDDATE
# Checked date: 2109-09-10 00:00:00.000000 UTC is valid.
# Checked date: 2109-09-13 00:00:00.000000 UTC is valid.
# Checked date: 2109-09-02 16:38:00.000000 UTC is valid.
# Checked date: 2109-09-13 14:00:00.000000 UTC is valid.
# Row 66 is valid.
# Checked date: 2109-09-10 00:00:00.000000 UTC is valid.
# Checked date: 2109-09-13 00:00:00.000000 UTC is valid.
# Checked date: 2110-10-08 16:35:00.000000 UTC is valid.
# Checked date: 2110-10-27 13:00:00.000000 UTC is valid.
# Row 67 is valid.
# Checked date: 2188-10-27 00:00:00.000000 UTC is valid.
# Checked date: 2188-10-29 00:00:00.000000 UTC is valid.
# Checked date: 2188-10-24 14:23:00.000000 UTC is valid.
# Checked date: 2188-11-18 14:30:00.000000 UTC is valid.
# Row 68 is valid.
# Checked date: 2159-03-03 00:00:00.000000 UTC is valid.
# Checked date: 2159-03-08 00:00:00.000000 UTC is valid.
# Checked date: 2159-01-25 14:39:00.000000 UTC is valid.
# Checked date: 2159-02-09 18:02:00.000000 UTC is valid.
# Row 69 is valid.
# Checked date: 2159-03-03 00:00:00.000000 UTC is valid.
# Checked date: 2159-03-08 00:00:00.000000 UTC is valid.
# Checked date: 2164-02-13 22:35:00.000000 UTC is valid.
# Checked date: 2164-02-16 12:00:00.000000 UTC is valid.
# Row 70 is valid.
# Checked date: 2159-03-03 00:00:00.000000 UTC is valid.
# Checked date: 2159-03-08 00:00:00.000000 UTC is valid.
# Checked date: 2156-12-27 00:35:00.000000 UTC is valid.
# Checked date: 2157-01-26 15:26:00.000000 UTC is valid.
# Row 71 is valid.
# Checked date: 2159-03-03 00:00:00.000000 UTC is valid.
# Checked date: 2159-03-08 00:00:00.000000 UTC is valid.
# Checked date: 2159-10-05 03:10:00.000000 UTC is valid.
# Checked date: 2159-10-10 16:10:00.000000 UTC is valid.
# Row 72 is valid.
# Checked date: 2159-03-03 00:00:00.000000 UTC is valid.
# Checked date: 2159-03-08 00:00:00.000000 UTC is valid.
# Checked date: 2163-07-18 14:46:00.000000 UTC is valid.
# Checked date: 2163-08-25 18:20:00.000000 UTC is valid.
# Row 73 is valid.
# Checked date: 2159-03-03 00:00:00.000000 UTC is valid.
# Checked date: 2159-03-08 00:00:00.000000 UTC is valid.
# Checked date: 2158-09-24 23:29:00.000000 UTC is valid.
# Checked date: 2159-01-23 13:57:00.000000 UTC is valid.
# Row 74 is valid.
# Checked date: 2159-03-03 00:00:00.000000 UTC is valid.
# Checked date: 2159-03-08 00:00:00.000000 UTC is valid.
# Checked date: 2159-02-13 09:13:00.000000 UTC is valid.
# Checked date: 2159-03-27 16:40:00.000000 UTC is valid.
# Row 75 is valid.
# Checked date: 2159-03-03 00:00:00.000000 UTC is valid.
# Checked date: 2159-03-08 00:00:00.000000 UTC is valid.
# Checked date: 2159-04-06 19:49:00.000000 UTC is valid.
# Checked date: 2159-04-16 14:00:00.000000 UTC is valid.
# Row 76 is valid.
# Checked date: 2176-11-24 00:00:00.000000 UTC is valid.
# Checked date: 2176-11-24 00:00:00.000000 UTC is valid.
# Checked date: 2171-06-24 18:13:00.000000 UTC is valid.
# Checked date: 2171-06-26 14:00:00.000000 UTC is valid.
# Row 77 is valid.
# Checked date: 2176-11-24 00:00:00.000000 UTC is valid.
# Checked date: 2176-11-24 00:00:00.000000 UTC is valid.
# Checked date: 2175-07-12 19:08:00.000000 UTC is valid.
# Checked date: 2175-08-01 16:14:00.000000 UTC is valid.
# Row 78 is valid.
# Checked date: 2176-11-24 00:00:00.000000 UTC is valid.
# Checked date: 2176-11-24 00:00:00.000000 UTC is valid.
# Checked date: 2176-11-24 08:01:00.000000 UTC is valid.
# Checked date: 2176-11-29 12:30:00.000000 UTC is valid.
# Row 79 is valid.
# Checked date: 2176-04-12 00:00:00.000000 UTC is valid.
# Checked date: 2176-04-20 00:00:00.000000 UTC is valid.
# Checked date: 2176-04-07 18:42:00.000000 UTC is valid.
# Checked date: 2176-04-20 10:31:00.000000 UTC is valid.
# Row 80 is valid.
# Checked date: 2144-03-01 00:00:00.000000 UTC is valid.
# Checked date: 2144-03-04 00:00:00.000000 UTC is valid.
# Checked date: 2144-02-26 15:26:00.000000 UTC is valid.
# Checked date: 2144-03-10 15:00:00.000000 UTC is valid.
# Row 81 is valid.
# Checked date: 2144-03-01 00:00:00.000000 UTC is valid.
# Checked date: 2144-03-04 00:00:00.000000 UTC is valid.
# Checked date: 2145-09-23 22:30:00.000000 UTC is valid.
# Checked date: 2145-10-01 17:15:00.000000 UTC is valid.
# Row 82 is valid.
# Checked date: 2144-03-01 00:00:00.000000 UTC is valid.
# Checked date: 2144-03-04 00:00:00.000000 UTC is valid.
# Checked date: 2142-07-06 11:00:00.000000 UTC is valid.
# Checked date: 2142-07-31 17:10:00.000000 UTC is valid.
# Row 83 is valid.
# Checked date: 2144-03-01 00:00:00.000000 UTC is valid.
# Checked date: 2144-03-04 00:00:00.000000 UTC is valid.
# Checked date: 2138-10-06 21:20:00.000000 UTC is valid.
# Checked date: 2138-10-22 16:37:00.000000 UTC is valid.
# Row 84 is valid.
# Checked date: 2193-04-10 00:00:00.000000 UTC is valid.
# Checked date: 2193-04-10 00:00:00.000000 UTC is valid.
# Checked date: 2192-09-24 16:41:00.000000 UTC is valid.
# Checked date: 2192-09-26 18:15:00.000000 UTC is valid.
# Row 85 is valid.
# Checked date: 2193-04-10 00:00:00.000000 UTC is valid.
# Checked date: 2193-04-10 00:00:00.000000 UTC is valid.
# Checked date: 2195-04-29 12:43:00.000000 UTC is valid.
# Checked date: 2195-05-14 14:31:00.000000 UTC is valid.
# Row 86 is valid.
# Checked date: 2193-04-10 00:00:00.000000 UTC is valid.
# Checked date: 2193-04-10 00:00:00.000000 UTC is valid.
# Checked date: 2193-04-07 16:49:00.000000 UTC is valid.
# Checked date: 2193-05-02 15:00:00.000000 UTC is valid.
# Row 87 is valid.
# Checked date: 2151-05-19 00:00:00.000000 UTC is valid.
# Checked date: 2151-05-22 00:00:00.000000 UTC is valid.
# Checked date: 2151-05-18 07:15:00.000000 UTC is valid.
# Checked date: 2151-06-01 13:09:00.000000 UTC is valid.
# Row 88 is valid.
# Checked date: 2148-12-11 00:00:00.000000 UTC is valid.
# Checked date: 2148-12-13 00:00:00.000000 UTC is valid.
# Checked date: 2148-12-02 21:43:00.000000 UTC is valid.
# Checked date: 2148-12-13 13:23:00.000000 UTC is valid.
# Row 89 is valid.
# Checked date: 2156-02-13 00:00:00.000000 UTC is valid.
# Checked date: 2156-02-14 00:00:00.000000 UTC is valid.
# Checked date: 2156-02-12 16:36:00.000000 UTC is valid.
# Checked date: 2156-02-17 14:44:00.000000 UTC is valid.
# Row 90 is valid.
# Checked date: 2174-03-28 00:00:00.000000 UTC is valid.
# Checked date: 2174-03-29 00:00:00.000000 UTC is valid.
# Checked date: 2174-03-12 01:20:00.000000 UTC is valid.
# Checked date: 2174-03-29 13:30:00.000000 UTC is valid.
# Row 91 is valid.
# Checked date: 2160-05-31 00:00:00.000000 UTC is valid.
# Checked date: 2160-06-03 00:00:00.000000 UTC is valid.
# Checked date: 2160-05-22 21:33:00.000000 UTC is valid.
# Checked date: 2160-06-10 16:53:00.000000 UTC is valid.
# Row 92 is valid.
# Checked date: 2160-05-31 00:00:00.000000 UTC is valid.
# Checked date: 2160-06-03 00:00:00.000000 UTC is valid.
# Checked date: 2160-12-07 02:55:00.000000 UTC is valid.
# Checked date: 2160-12-22 20:24:00.000000 UTC is valid.
# Row 93 is valid.
# Checked date: 2160-05-31 00:00:00.000000 UTC is valid.
# Checked date: 2160-06-03 00:00:00.000000 UTC is valid.
# Checked date: 2159-10-17 15:22:00.000000 UTC is valid.
# Checked date: 2159-11-08 17:15:00.000000 UTC is valid.
# Row 94 is valid.
# Checked date: 2130-07-10 00:00:00.000000 UTC is valid.
# Checked date: 2130-07-11 00:00:00.000000 UTC is valid.
# Checked date: 2130-06-29 00:14:00.000000 UTC is valid.
# Checked date: 2130-07-11 17:30:00.000000 UTC is valid.
# Row 95 is valid.
# Checked date: 2189-02-15 00:00:00.000000 UTC is valid.
# Checked date: 2189-02-17 00:00:00.000000 UTC is valid.
# Checked date: 2189-03-19 11:55:00.000000 UTC is valid.
# Checked date: 2189-03-24 12:59:00.000000 UTC is valid.
# Row 96 is valid.
# Checked date: 2189-02-15 00:00:00.000000 UTC is valid.
# Checked date: 2189-02-17 00:00:00.000000 UTC is valid.
# Checked date: 2189-02-12 14:00:00.000000 UTC is valid.
# Checked date: 2189-02-21 16:20:00.000000 UTC is valid.
# Row 97 is valid.
# Checked date: 2130-06-29 00:00:00.000000 UTC is valid.
# Checked date: 2130-07-11 00:00:00.000000 UTC is valid.
# Checked date: 2130-06-29 00:14:00.000000 UTC is valid.
# Checked date: 2130-07-11 17:30:00.000000 UTC is valid.
# Row 98 is valid.
# Checked date: 2178-04-21 00:00:00.000000 UTC is valid.
# Checked date: 2178-04-30 00:00:00.000000 UTC is valid.
# Checked date: 2178-04-21 18:22:00.000000 UTC is valid.
# Checked date: 2178-04-30 13:30:00.000000 UTC is valid.
# Row 99 is valid.
# Total valid rows: 97, Invalid rows: 3
# Percentage of valid rows: 97.00%
